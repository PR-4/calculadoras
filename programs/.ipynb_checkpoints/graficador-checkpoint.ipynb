# %%
######################PACOTES##########################
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import logging
import seaborn as sns
sys.path.insert(0,'../modules')
from graficador import plotagem as plm2
#######################################################

# %%
#----------------------------------------------------------------------#
# Leitura do data frame que contém os canais da perfilagem             #
#----------------------------------------------------------------------#
df = pd.read_csv("../entradas/UFF_ESS37C.las", sep='\s+', skiprows=36 , 
                 names=('Depth(m)','NPHI','DT','GR','RHOB','CALI','ILD','LITO'))

# %%
#Filtra os expúrios ferramentais:
#df=df[(df['RHOB'] != -99999.0) & (df['RHOB'] != -999999.9999)] 
#df=df[(df['DT'] != -99999.0) & (df['DT'] != -999999.9999)]
df=df[(df['GR'] != -99999.0) &  (df['GR'] != -999999.9999)]
#df=df[(df['CALI'] != -99999.0) &  (df['CALI'] != -999999.9999)]
#df=df[(df['NPHI'] != -99999.0) &  (df['NPHI'] != -999999.9999)]
#df=df[(df['ILD'] != -99999.0) &  (df['ILD'] != -999999.9999)]

# %%
#----------------------------------------------------------#
#            Filtra trechos desmoronados:                  #
#----------------------------------------------------------#
#Parametros do poço:
# diametro = 9 pol
# lam = +/- 2 pol (limite aceitavel maximo)
dim = 9
delta = 2
ls = dim + delta
li = dim - delta

#I - filtragem caliper:

#df=df[(df['CALI'] >= li) & (df['CALI'] <= ls)]#informação baseada diametro do poco

# II - filtragem visual: selecao de um alvo especifico idade ou grupo
#topo =1750.0
#base = 2300.0
#df=df[(df['Depth1(m)'] >= topo) & (df['Depth1(m)'] <= base)] # alvo!

# %%
prof=np.array(df['Depth(m)'])
NPHI=np.array(df['NPHI'])
DT=np.array(df['DT'])
GR=np.array(df['GR'])
RHOB=np.array(df['RHOB'])
CALI=np.array(df['CALI'])
ILD=np.array(df['ILD'])
cod=np.array(df['LITO'])

# %%
for i in range(len(cod)):
    print(cod[i])
# Out:
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# 8
# ...

# %%
codigos =  pd.read_csv("../entradas/codigos.txt", sep='\s+', usecols=(0,1,2,3), 
                   index_col=False, na_values= ' ', skiprows=0, names=('ROCK', 'AlPH', 'HEX', 'NUM') )

# %%
d =  dict([(i,[a,b]) for i,a,b in zip(codigos['NUM'], codigos['HEX'],codigos['ROCK'])])
print(d)
# Out:
# {57: ['#40ff00', 'FOLHELHO'], 49: ['#ffff40', 'ARENITO'], 58: ['#2f0eff', 'MARGA'], 44: ['#10ef60', 'DIAMICTITO'], 42: ['#ffbf20', 'CONGLOMERADO'], 8: ['#0080ef', 'CALCITIC_SANDSTONE'], 6: ['#50ffff', 'CALCITIC_MUDSTONE'], 12: ['#7faeae', 'MUDSTONE'], 14: ['#18b1f1', 'PACKSTONE'], 74: ['#ff3f3f', 'QUARTZITO'], 68: ['#e98918', 'RIOLITO'], 84: ['#8e1ddd', 'SAL_NI'], 9: ['#e98918', 'SIDERITA'], 94: ['#beffff', 'SILEXITO'], 54: ['#af1d4e', 'SILTITO'], 86: ['#cda0dd', 'SILVINITA'], 91: ['#ffff3f', 'TALCOESTIVENCITA'], 81: ['#6d1ddd', 'TAQUIDRITA'], 46: ['#2fec5d', 'TILITO'], 59: ['#dddddd', 'TOBA'], 43: ['#ffff3f', 'TOBA_ARENOSA'], 45: ['#7eff00', 'TOBA_ARGILOSA'], 47: ['#af1d4e', 'TOBA_SILTICA'], 61: ['#ff5dbe', 'TUFO_VULCANICO'], 78: ['#00a000', 'ULTRABASICA'], 34: ['#ffbe1d', 'VULCANICA_NI'], 13: ['#33d8f9', 'WACKESTONE'], 73: ['#ff5d5d', 'XISTO'], 64: ['#ff0000', 'IGNEA_NI'], 65: ['#ff00ff', 'DIABASIO'], 66: ['#ff00ff', 'BASALTO'], 67: ['#ff0000', 'GRANITO'], 70: ['#ff0000', 'METAMORF
# ...

# %%
padrao={'comprimento':5,
            'altura':20
}
#Desenha os plots
figure2 = plm2(2, padrao)
figure2.plot_l2(0,cod,prof, d ,{'titulo':'Lithology', 'descricao_y':'Depth(m)','descricao_x':'(a)'})
figure2.plot_s(1,GR,prof,{'titulo':'GR \n (ci/g)','cor':'r','descricao_x':'(b)'})

figure2.legenda({'ancoragem':(-0.3, 0.09, 3.0, -0.16),'colunas':2,'ordem':[0,1,2,3,6,7] })


plt.savefig('../imagens/perfilcomposto.pdf', dpi=300, bbox_inches = 'tight', transparent = True)

# %% [markdown]
# # Analisando poço via biblioteca lasio

# %%
# !pip install lasio

# %%
import lasio
#Configurando figura e o rc parameters
# %config InlineBackend.figure_format='retina'
plt.rcParams["figure.figsize"] = (20,8)
plt.rc('text', usetex=True)
plt.rc('font', family='serif', size = 18)

# %%
las = lasio.read("../entradas/UFF_ESS37C.las")

# %%
las.sections.keys()
# Out:
# dict_keys(['Version', 'Well', 'Curves', 'Parameter', 'Other'])

# %%
las.sections['Version']
# Out:
# [HeaderItem(mnemonic="VERS", unit="", value="2.0", descr="CWLS Log ASCII Standa"),
#  HeaderItem(mnemonic="WRAP", unit="", value="NO", descr="One Line per Depth Ste")]

# %%
for item in las.sections['Well']:
    print(f"{item.descr} ({item.mnemonic}): \t\t {item.value}")
# Out:
# Start Depth (STRT): 		 490.2
# Stop  Depth (STOP): 		 5244.8
# Step (STEP): 		 0.2
# Null Value (NULL): 		 -99999.0
# Company (COMP): 		 PETROLEO BRASILEIRO S/A
# Origem dos dados (ORIG): 		 SIGEO EXPORTACAO PERFIL
# Well (WELL): 		 1ESS 0037C ES
# Field (FLD):
# State (STAT): 		 ESPIRITO SANTO
# API Code (API): 		 342710046100
# Surface X (X): 		 450490.6
# Surface Y (Y): 		 7824661.98
# Horizontal Coordinate System (HZCS): 		 UTM
# Meridiano Central (MC): 		 39 W
# Latitude (LATI): 		 -19:40:21.926
# Longitude (LONG): 		 -39:28:20.370
# Geodetic Datum (GDAT): 		 SIRGAS2000
# Log Measure From (LMF): 		 MR
# Elevation Derrick Floor (EDF): 		 24.0
# Water Depth to Mean Sea Level (WDMS): 		 64.0

# %%
#las.sections['Well']['WELL'] = 'Brasil'

# %%
for curve in las.curves:
    print(curve.mnemonic)
# Out:
# DEPT
# NPHI
# DT
# GR
# RHOB
# CALI
# ILD
# LITO

# %%
for count, curve in enumerate(las.curves):
    print(f"Curve: {curve.mnemonic}, \t Units: {curve.unit}, \t Description: {curve.descr}")
print(f"There are a total of: {count+1} curves present within this file")
# Out:
# Curve: DEPT, 	 Units: M, 	 Description: Measured Depth
# Curve: NPHI, 	 Units: %, 	 Description: THERMAL NEUTRON POROSITY (ORIGINAL RATIO METHOD) IN SELECTED LITHOLOGY
# Curve: DT, 	 Units: us/ft, 	 Description: DELTA-T (ALSO CALLED SLOWNESS OR INTERVAL TRANSIT TIME)
# Curve: GR, 	 Units: gAPI, 	 Description: GAMMA RAY
# Curve: RHOB, 	 Units: g/cm3, 	 Description: BULK DENSITY
# Curve: CALI, 	 Units: in, 	 Description: CALIPER
# Curve: ILD, 	 Units: ohm.m, 	 Description: INDUCTION DEEP RESISTIVITY
# Curve: LITO, 	 Units: , 	 Description:
# There are a total of: 8 curves present within this file

# %% [markdown]
# # Convertendo em um pandas dataframe

# %%
well = las.df()
well.head()
# Out:
#        NPHI        DT       GR    RHOB     CALI     ILD  LITO
# DEPT
# 490.2   NaN  176.3425  29.6142  1.5165  16.8461  4.9730   8.0
# 490.4   NaN  185.5129  31.8610  1.5538  19.4223  2.2722   8.0
# 490.6   NaN  177.9147  33.9703  1.6135  19.9012  1.6519   8.0
# 490.8   NaN  160.6969  34.6545  1.6412  19.9012  1.3218   8.0
# 491.0   NaN  144.4675  33.8553  1.6750  19.9012  1.1997   8.0

# %%
well.describe()
# Out:
#               NPHI            DT            GR          RHOB          CALI  \
# count  6620.000000  23701.000000  23736.000000  23703.000000  15351.000000
# mean     20.263255     88.501491     78.813141      2.441054     13.727410
# std       8.963169     19.755545     23.067447      0.200510      5.396619
# min      -0.300600     43.381200     17.451200      1.449100      1.500000
# 25%      13.434000     76.115600     61.740675      2.383750      9.827200
# 50%      20.096850     82.823700     81.194100      2.508000     11.801400
# 75%      28.099500     96.735300     94.213000      2.576400     18.831500
# max      39.790300    191.706600    337.837400      2.900800     19.950600
#
#                 ILD          LITO
# count  23772.000000  23773.000000
# mean       3.498074     47.634039
# std        3.351486     18.049740
# min        0.296900      6.000000
# 25%        1.674900     49.000000
# 50%        2.653500     57.000000
# 75%        4.324925     57.000000
# ...

# %%
well.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 23773 entries, 490.2 to 5244.6
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NPHI    6620 non-null   float64
#  1   DT      23701 non-null  float64
#  2   GR      23736 non-null  float64
#  3   RHOB    23703 non-null  float64
#  4   CALI    15351 non-null  float64
#  5   ILD     23772 non-null  float64
#  6   LITO    23773 non-null  float64
# dtypes: float64(7)
# memory usage: 1.5 MB

# %%
well.plot()
plt.savefig('../imagens/perfis.pdf', dpi=300, bbox_inches = 'tight', transparent = True)

# %%
well.plot(y='GR')
plt.savefig('../imagens/raiogama.pdf', dpi=300, bbox_inches = 'tight', transparent = True)

# %%
well.plot(y='RHOB')
plt.savefig('../imagens/densidade.pdf', dpi=300, bbox_inches = 'tight', transparent = True)
